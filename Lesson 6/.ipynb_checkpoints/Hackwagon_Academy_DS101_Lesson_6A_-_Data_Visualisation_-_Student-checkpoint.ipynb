# %% [markdown]
# <center><img src="https://i2.wp.com/hackwagon.com/wp-content/uploads/2017/02/Logo-Web-Export.png?ssl=1" width=200/></center>
#
# <h1> Hackwagon Academy DS101 Lesson 6A </h1>
# <h2> Data Visualisation </h2>
# <h3> Lesson Outline </h3>
#
# - 1. [Data Science Project Pipeline](#1)
#     - 1.1 [Where You Are At For DS101](#1.1)
# - 2. [Visualisations](#1)
# - 3. [Matplotlib](#3)
#     - 3.1 [Line Chart](#3.1)
#     - 3.2 [Bar Chart](#3.2)
#     - 3.3 [Scatter Plot](#3.3)
#     - 3.4 [Designing Your Plots](#3.4)
#         - 3.4.1 [Title, Labels, Ticks, Colors](#3.4.1)
#         - 3.4.2 [Markers, Alphas, Sizes](#3.4.2)
#         - 3.4.3 [Saving Figures](#3.4.3)
#     - 3.5 [Subplots and Axes](#3.5)

# %% [markdown]
# <a id='1'><h2><img src="https://images.vexels.com/media/users/3/153978/isolated/preview/483ef8b10a46e28d02293a31570c8c56-warning-sign-colored-stroke-icon-by-vexels.png" width=25 align="left"><font color="salmon">&nbsp;1.</font><font color="salmon"> Data Science Project Stages </font> </h2></a>
#
# <img src="https://i.imgur.com/NzCT5EB.png">

# %% [markdown]
# <a id='2'><h2><img src="https://images.vexels.com/media/users/3/153978/isolated/preview/483ef8b10a46e28d02293a31570c8c56-warning-sign-colored-stroke-icon-by-vexels.png" width=25 align="left"><font color="salmon">&nbsp;2.</font><font color="salmon"> Visualisations </font> </h2></a>
#
# Data visualisations are the best ways to show what your data is about. When used correctly, visualisations can be used to tell fantastic stories. Steps to creating visualisation is very simple, but creating <b>effective and informative visualisations</b> can be challenging.

# %%
from IPython.display import HTML

HTML('''
  <iframe width="800" height="500" src="https://www.youtube.com/embed/jbkSRLYSojo" 
          frameborder="0" allow="accelerometer; autoplay; encrypted-media; 
          gyroscope; picture-in-picture" allowfullscreen>
  </iframe>
''')
# Out:
#   <iframe width="800" height="500" src="https://www.youtube.com/embed/jbkSRLYSojo"
#           frameborder="0" allow="accelerometer; autoplay; encrypted-media;
#           gyroscope; picture-in-picture" allowfullscreen>
#   </iframe>

# %% [markdown]
# <a id='3'><h2><img src="https://images.vexels.com/media/users/3/153978/isolated/preview/483ef8b10a46e28d02293a31570c8c56-warning-sign-colored-stroke-icon-by-vexels.png" width=25 align="left"><font color="salmon">&nbsp;3.</font><font color="salmon"> Matplotlib </font> </h2></a>
#
# Matplotlib is one of the most used and earliest Python visualisation libraries out there.
#
# Pros:
# 1. Provides a standard for other visualisation libraries
# 2. Leveraged by many other libraries
#
# Cons:
#
#  1. Documentation that is difficult to understand
#  2. Restrictive syntax
#
# Some examples of visualisations can be seen here: https://matplotlib.org/gallery/index.html
#
# Creating visualisations is <b>very simple</b>, just tell yourself that you need 2 <b>lists</b> of data of the same <b>length</b> and put them into the library's function and <b><i>it just works!</i></b>

# %%
import random
def create_random_numbers(how_many):
    results = []
    for i in range(how_many):
        results.append(random.randrange(1,101,1))
    return results

# %%
#make sure you import the library
import matplotlib.pyplot as plt

# %% [markdown]
# <a id="3.1"> <h3>3.1 Line Chart</h3></a>
#
# Line charts are best used for <b>time-series</b> data.
#
# <img src="https://plot.ly/~MelissaZhu/4.png" width="400">

# %%
# plt.plot(x,y
x= sorted(create_random_numbers(10))
y = create_random_numbers(10)
plt.plot(x,y)

# %% [markdown]
# <a id="3.2"> <h3>3.2 Bar Chart</h3></a>
#
# Bar charts are based used to find <b>differences between categories</b> or for <b>time-series</b> data.
#
# <img src="https://www.excel-easy.com/examples/images/bar-chart/bar-chart.png" width="400">
# <img src="http://thedailyviz.com/wp-content/uploads/2012/08/guns-620x415.png" width="400">

# %%
# plt.bar(categories,y)
# categories = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
categories =['a','b','c','d','e','f','g','h','i','j']
y= create_random_numbers(len(categories))
print(y)
plt.bar(categories,y)
# Out:
# [37, 20, 60, 60, 37, 49, 37, 84, 13, 28]
# <BarContainer object of 10 artists>

# %% [markdown]
# <a id="3.3"> <h3>3.3 Scatter Plot</h3></a>
# Scatter plots are best used for <b>relationships</b> between 2 or more variables.
#
# <img src="https://plot.ly/~cufflinks/52/life-expectancy-vs-gdp-per-capita.png" width="400">

# %%
x= sorted(create_random_numbers(100))
y= sorted(create_random_numbers(100))
plt.scatter(x,y)

# %% [markdown]
# <a id="3.4"> <h3>3.4 Designing Your Plots</h3></a>
#
# Don't aim to make simple visualisations, aim to make <b>informative and effective visualisations</b>. Here are some of the things to take note to make sure your visualisations is informative effective:
#
# 1. What is the story you want to tell?
# 2. Is the visualisation simple to understand?
# 3. Is the visualisation/chart appropriate based the given dataset?

# %% [markdown]
# <a id="3.4.1"> <h4>3.4.1 Titles, Labels, Color</h4></a>
#
# - Title - `plt.title()`
# - X Axis Label - `plt.xlabel()`
# - Y Axis Label - `plt.ylabel()`
# - Color - `c=`

# %%
x = create_random_numbers(10)
x.sort()
print(x)
y = create_random_numbers(10)
y.sort()
print(y)

plt.scatter(x,y)
plt.title("Relationship between age and wealth")
plt.xlabel("Age in years")
plt.ylabel("wealth in dollars")
# Out:
# [1, 10, 12, 19, 26, 43, 60, 73, 74, 77]
# [8, 9, 33, 37, 64, 70, 75, 78, 94, 94]
# Text(0, 0.5, 'wealth in dollars')

# %% [markdown]
# <a id="3.4.2"> <h4>3.4.2 Markers, Alphas, Size</h4></a>
#
# When designing scatterplots, sometimes you want certain points to be more distinct than the others.
#
# - Markers - Design of each point: `marker=`
# - Alphas - Darkness of each point: `alpha=`
# - Size - Size of each point: `s=`

# %%
x1 = create_random_numbers(10)
x1.sort()
print(x)
y1 = create_random_numbers(10)
y1.sort()
print(y1)

plt.scatter(x1,y1, marker="*", s=400, c="gold")
y2= create_random_numbers(10)
x2=create_random_numbers(10)
plt.scatter(x2,y2,marker="o", s =400,c="green", alpha =0.3 ) #alpha is 0-1 0 is transparent, 1 opaque
# Out:
# [1, 10, 12, 19, 26, 43, 60, 73, 74, 77]
# [3, 13, 13, 23, 35, 39, 40, 80, 95, 96]

# %% [markdown]
# <a id="3.4.3"> <h4>3.4.3 Saving Figures</h4></a>
#
# After designing your graphs, you might want to use it for presentation purposes. You can save your chart by doing `plt.savefig()`.

# %%
x = create_random_numbers(10)
x.sort()
print(x)
y = create_random_numbers(10)
y.sort()
print(y)
plt.scatter(x,y,marker="h",s=300,c="orange")
#save file here
plt.savefig("Donald Trump")# or whatever name lah.. it will save plot
# Out:
# [16, 16, 18, 18, 35, 57, 69, 75, 93, 94]
# [5, 23, 23, 26, 37, 46, 63, 69, 76, 88]

# %% [markdown]
# <a id="3.5"> <h3>3.5 Subplots & Axes</h3></a>
#
# Sometimes it is better to have different plots side-by-side, for example you want to compare times-series and scatterplot graphs of the same dataset. This is where we will use <b>subplots / axes</b>. Here we will understand how to use these subplots.
#
# <img src="https://i.imgur.com/JrukTTS.png" width="300">

# %%
# fig = plt.figure(figsize = (16,6))
# ax1 = fig.add_subplot(1,1,1)
# ax1.scatter(x,y)
x=sorted(create_random_numbers(10))
y= create_random_numbers(10)
categories=['a','b','c','d','e','f','g','h','i','j']

fig = plt.figure(figsize = (16,6))
ax1 = fig.add_subplot(2,2,1) # 2 rows, 2 columns, first figure
ax1.scatter(x,y)
ax1a = fig.add_subplot(2,2,2) # 2 rows, 2 columns, second figure (first row)
ax1a.plot(x,y)
ax2 = fig.add_subplot(2,2,3) # 2 rows, 2 columns, third figure (first figure in second row)
ax2.bar(categories,y)
ax2a = fig.add_subplot(2,2,4) # 2 rows, 2 columns, fourth figure (second figure in second row)
ax2a.plot(x,y)
# Smiley-face layout:
# left_top = fig.add_subplot(2,2,1)
# right_top = fig.add_subplot(2,2,2)
# bottom = fig.add_subplot(1,2,2) # (second row figure)
